# %% [markdown]
# # Ejercicio: Mi primer push con Git
#
# > Antes de llegar aca, seguí los pasos del **README de la clase 07**:
# > registro en la API, clonar el repo y crear tu rama personal.

# %% [markdown]
# ---
#
# ## Unirse al listado oficial
#
# Completa tus datos en la siguiente celda y ejecutala con **Shift+Enter**.
# Esto genera un archivo `.md` con tu registro en la carpeta `alumnos/`.

# %%
import os
import subprocess

nombre_completo = ' '    # <-- Completar
email = ' '          # <-- Completar
github_user = ' '      # <-- Completar

os.makedirs('alumnos', exist_ok=True)

# Nombre de archivo seguro
clean_name = github_user.lower().replace(' ', '_')
filename = f'alumnos/{clean_name}.md'

content = f"""# Registro Inicial GitHub

- **Alumno**: {nombre_completo}
- **Email**: {email}
- **Github**: @{github_user}

Infraestructura para Ciencia de Datos.
"""

with open(filename, 'w', encoding='utf-8') as f:
    f.write(content)

print(f'✅ Archivo creado localmente: {filename}')

# %% [markdown]
# ---
#
# ## Siguiente paso
#
# Volve a la terminal (que debería estar en la carpeta `LCD-InfraCienciaDatos/`) y ejecuta:
#
# ```bash
# git add ./clase07/ejercicio/alumnos/
# git commit -m "registro: Garcia, Juan"
# git push origin registro-garcia-juan
# ```
#
# > **Importante**: Reemplaza `Garcia Juan` y `garcia-juan` con **tu nombre real** en ambos comandos.
#
# ---
#
# > **Nota 1 **: Si es la primera vez que pusheas al repo, Git te va a pedir que te loguees:
# >
# > Por mas que te pida el password (en realidad se refiere al PAT - personal access token que tenes que registrar desde github)
# >
# > - GitHub → Settings → Developer settings → Personal access tokens → Tokens (classic)
# > - Generate new token → seleccioná al menos el scope repo
# > - Copiá el token (solo se muestra una vez)
#
#
#
# ---
#
#
# > **Nota 2 **: Si es la primera vez que pusheas esta rama, Git te va a pedir que ejecutes:
# > `git push --set-upstream origin registro-garcia-juan`
# >
# > Esto es normal, solo pasa la primera vez.
#
# ---
#
# Luego abri un **Pull Request** en GitHub hacia `main`.
